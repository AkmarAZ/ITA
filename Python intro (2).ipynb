# %% [markdown]
# ----------------------------------------------------------![image.png](attachment:image.png)-------------------------------------------------
#
# ##### ---------------------------------------------------------- TS NURUL AKMAR AZMAN---------------------------------------------------------
#
#
#
# # Introduction to Python

# %% [markdown]
# ### Why Python?
#
# 1. It’s easy to learn
# - Now the language of choice for 8 of 10 top US computer science
# programs (Philip Guo, CACM)
# 2. Full featured
# - Not just a statistics language, but has full capabilities for data
# acquisition, cleaning, databases, high performance computing, and more
# 3. Strong Data Libraries
# - Numpy, SciPy, Scikit-learn etc
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # How to use python??
# ## Developer Choice
# ********************
# ![image.png](attachment:image.png)Using Visual Studio Code (VSCode) for Python development is a popular choice among developers due to its versatility, extensive plugin ecosystem, and lightweight nature.
#
# ## For Beginners
# ***********************
# ![image-2.png](attachment:image-2.png)
# Jupyter Notebook provides a powerful environment for writing, executing, and documenting Python code with interactive features and rich text formatting capabilities.
# By combining code cells with Markdown cells, you can create cohesive and well-documented Python projects and analyses.
#
# ------------------------------------------

# %% [markdown]
# ### Your first program: Print!
#
# Your top priority when coding is seeing the output.
# 'print' lets you display messages, variables, or anything you want right there in your console or output window. It's super handy for checking values, debugging, or just saying hi from your program to the world. So, whenever you want to show something in Python, 'print' is your go-to buddy!
#
#
# Python can handle strings of letters that are enclosed in quotation marks like:
#
# `"My hobby is travelling"` or `'I love Travelling'`
#
# Try it on your own!

# %% [markdown]
# ### print
#
# type **print("Hello World")** and observe the difference

# %% [markdown]
# # Comments
# ## we use comments to make code readable or prevent code execution
# Try your python comments in the code box with = I love python

# %% [markdown]
# # Python Identation
# Indentation is a very important concept of Python because without properly indenting the Python code, you will end up seeing IndentationError and the code will not get compiled.
#
# All the statements with the same space to the right, belong to the same code block.

# %%
a = 'bcd'
 
if a == 'bcd':
    print('Alphabet')
else:
    print('nan')
print('Reset')

# %% [markdown]
# # Variables
#
# Variables are used to store data.
# Don’t need to declare the data type of a variable explicitly.
# Python will automatically infer the data type based on the value assigned to the variable.
#
# x = 10  # Integer
#
# y = 3.14  # Float
#
# name = "John"  # String

# %% [markdown]
# # Data Types
# Python supports various data types, including integers, floats, strings, lists, tuples, dictionaries, and more.
#
# Integers: Whole numbers without decimals.
#
# Floats: Numbers with decimals.
#
# Strings: Text enclosed in single or double quotes.
#
# Lists: Ordered collections of items.
#
# Tuples: Immutable collections of items.
#
# Dictionaries: Key-value pairs.
#
# ------------------------------------------------------------------------------------------------------------------------
# using 'type' :
#
# -find data types of 10 , 10.0 , 10<9 and 'ten'

# %%
#data type

# %%
x=[a,b,c]
type(x)

# %% [markdown]
# # Arithmetic
#
# Python can also handle numbers, and basic arithmetic using the following functions.
#
# | Symbol | Task Performed |
# |----|---|
# | +  | Addition |
# | -  | Subtraction |
# | /  | division |
# | %  | modulo |
# | *  | multiplication |
# | //  | floor division |
# | **  | to the power of |

# %%
print(3)
print(3*5)
print(3+3)
print(3-2)
print(8/2)

# %% [markdown]
# **Type the following and observe the difference**
#
# 3
#
# 3*5
#
# 3+3
#
# 3-2
#
# 8/2

# %% [markdown]
# ### Practice: Basic Arithmetic Exercises

# %%
# What is the duration of 2-days  in minutes?

# %%
# Calculate the area of a 3m by 5m plot.

# %%
# A cone has a base radius of 4 cm and a height of 9 cm. Calculate the volume of the cone. (Use 𝜋=3.14 and the formula 𝑉=1/3𝜋𝑟^2ℎ)

# %% [markdown]
# ### Integers vs. Float
#
# For Python 2.x, it interprets 1/2 = 0, while Python 3.x the result will be 0.5

# %%
print(1/2)

# %%
print((type(10)))
print((type(10.)))
print((10 / 3))
print((10 % 3))
print((float(10) / 3)) # Force integers to be float
print((13.0 / 3.5)) # You can also change the initial data type. 
print((13.0 //3.5)) # Floor Division, rounds down the result to the nearest integer
print((round(7.5))) # You can round floats up to the neares integer.

# %% [markdown]
# ### Exercise
#
# Find **x** in 5x = 3x + 8

# %% [markdown]
# ### Try to run the following code:

# %%
print(5.5 + 2.2)
print(5.5 - 2.2)
print(5.5 * 2.2)
print(5.5 / 2.2)
print(5.5 // 2.2)
print(5.5 ** 2.2)
print(5.5 < 2.2)
print(5.5 != 2.2)
# Variables

# %% [markdown]
# # Data type

# %%
b = -10 
c = 2.7 

print(b)
print(c)
print((b + c))

print((type(b)))
print((type(c)))
print((type(b+c)))

# %%
print(b**5)
print(b+c*(b/c))

# %% [markdown]
# ### Change the data type

# %%
b = float(b)
c = int(c)

print(b)
print(c)

print((type(b)))
print((type(c)))
